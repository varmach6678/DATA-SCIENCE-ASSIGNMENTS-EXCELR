# %%
import pandas as pd
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data = pd.read_csv('Online retail.csv')
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
data.tail()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt

# %%
data.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# count                                                7500
# unique                                               5175
# top                                               cookies
# freq                                                  223

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                           --------------  -----
#  0   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil  7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB
# ...

# %%
sample_data = data.sample(n=20, random_state=42)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(sample_data)
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 970                                      eggs,champagne
# 6279                                       burgers,milk
# 1859       tomatoes,french fries,body spray,yogurt cake
# 6803                                            cookies
# 6305                              mineral water,carrots
# 3039  shrimp,mineral water,milk,almonds,whole wheat ...
# 7194                             burgers,escalope,pasta
# 1446                                       french fries
# 5199   grated cheese,herb & pepper,french fries,cookies
# 6234  tomatoes,mineral water,eggs,ketchup,corn,pancakes
# 4316                                    shrimp,tomatoes
# 5922                              mineral water,avocado
# 6027                         milk,brownies,tomato juice
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# Sample transactions
transactions = [
    ['burgers', 'meatballs', 'eggs'],
    ['chutney'],
    ['turkey', 'avocado'],
    ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
    ['low fat yogurt'],
    ['eggs,champagne'],
    ['burgers,milk'],
    ['tomatoes,french fries,body spray,yogurt cake '],
    ['cookies'],
    ['mineral water,carrots']

]
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_binary = pd.DataFrame(te_ary, columns=te.columns_)

# Display the transformed dataframe
print(df_binary.head())
# Out:
#    avocado  burgers  burgers,milk  chutney  cookies   eggs  eggs,champagne  \
# 0    False     True         False    False    False   True           False
# 1    False    False         False     True    False  False           False
# 2     True    False         False    False    False  False           False
# 3    False    False         False    False    False  False           False
# 4    False    False         False    False    False  False           False
#
#    energy bar  green tea  low fat yogurt  meatballs   milk  mineral water  \
# 0       False      False           False       True  False          False
# 1       False      False           False      False  False          False
# 2       False      False           False      False  False          False
# 3        True       True           False      False   True           True
# 4       False      False            True      False  False          False
#
# ...

# %%
# Apply the Apriori algorithm to find frequent itemsets with a minimum support of 0.02
frequent_itemsets = apriori(df_binary, min_support=0.02, use_colnames=True)

# Display the frequent itemsets
print(frequent_itemsets)
# Out:
#     support                                           itemsets
# 0       0.1                                          (avocado)
# 1       0.1                                          (burgers)
# 2       0.1                                     (burgers,milk)
# 3       0.1                                          (chutney)
# 4       0.1                                          (cookies)
# 5       0.1                                             (eggs)
# 6       0.1                                   (eggs,champagne)
# 7       0.1                                       (energy bar)
# 8       0.1                                        (green tea)
# 9       0.1                                   (low fat yogurt)
# 10      0.1                                        (meatballs)
# 11      0.1                                             (milk)
# 12      0.1                                    (mineral water)
# 13      0.1                            (mineral water,carrots)
# ...

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3, num_itemsets=len(frequent_itemsets))

print(rules)
# Out:
#             antecedents                                        consequents  \
# 0             (avocado)                                           (turkey)
# 1              (turkey)                                          (avocado)
# 2                (eggs)                                          (burgers)
# 3             (burgers)                                             (eggs)
# 4           (meatballs)                                          (burgers)
# ..                  ...                                                ...
# 189     (mineral water)    (energy bar, green tea, milk, whole wheat rice)
# 190         (green tea)  (energy bar, mineral water, whole wheat rice, ...
# 191        (energy bar)  (mineral water, green tea, milk, whole wheat r...
# 192  (whole wheat rice)       (energy bar, mineral water, green tea, milk)
# 193              (milk)  (energy bar, mineral water, green tea, whole w...
#
# ...

# %% [markdown]
# INTERVIEW QUESTIONS
#
# 1.What is lift and why is it important in Association rules?
#
# Ans
#
# Lift is a measure used in association rule mining to evaluate the strength of an association rule compared to the expected likelihood of the items being associated if they were independent. In simpler terms, lift tells you how much more likely the items in the rule are to occur together than would be expected by chance.

# %% [markdown]
# 2.What is support and Confidence. How do you calculate them?
#
# Ans
#
# Support:
# Support measures how frequently an itemset (or rule) appears in the dataset. It indicates the proportion of transactions that contain a specific item or itemset.
#
# Formula:
# Support
# (
# 𝐴
# )
# =
# Number of transactions containing A
# Total number of transactions
# Support(A)=
# Total number of transactions
# Number of transactions containing A
#
#  Confidence:
# Confidence measures the likelihood that an item B is purchased when item A is purchased. It is the probability of the consequent given the antecedent in a rule.
#
# Formula:
# Confidence
# (
# 𝐴
# ⇒
# 𝐵
# )
# =
# Support
# (
# 𝐴
# ∪
# 𝐵
# )
# Support
# (
# 𝐴
# )
# Confidence(A⇒B)=
# Support(A)
# Support(A∪B)
# ​

# %% [markdown]
# 3.	What are some limitations or challenges of Association rules mining?
#
# Ans
#
# Some limitations or challenges of association rule mining include handling large datasets, dealing with noisy or incomplete data, and generating an overwhelming number of rules, many of which may be trivial or redundant.
